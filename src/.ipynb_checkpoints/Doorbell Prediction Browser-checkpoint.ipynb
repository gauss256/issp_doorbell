# %%
# %matplotlib inline
import csv
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy import misc
from ipywidgets import interact

# %%
# Find the most recent submission file
summary_dir = os.path.expanduser('~/Doorbell/src/summaries/')
submission_files = sorted(glob.glob(os.path.join(summary_dir,'*.csv')))
submission_file = submission_files[-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-a405ff6947b2> in <module>()
#       2 summary_dir = os.path.expanduser('~/Doorbell/src/summaries/')
#       3 submission_files = sorted(glob.glob(os.path.join(summary_dir,'*.csv')))
# ----> 4 submission_file = submission_files[-1]
#
# IndexError: list index out of range

# %%
# Read the submission entries into a list
with open(submission_file, 'rb') as f:
    predictions = np.array(list(csv.reader(f)))
predictions = predictions[1:]
predictions[0]
image_names = predictions[:,0]
p0 = predictions[:,1].astype(float)
p1 = predictions[:,2].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3ce3fcba714c> in <module>()
#       1 # Read the submission entries into a list
# ----> 2 with open(submission_file, 'rb') as f:
#       3     predictions = np.array(list(csv.reader(f)))
#       4 predictions = predictions[1:]
#       5 predictions[0]
#
# NameError: name 'submission_file' is not defined

# %%
image_dir = os.path.expanduser('~/Doorbell/images/test')

# %%
def browse_images(tests):
    n = len(tests)
    def view_image(i):
        im = misc.imread(os.path.join(image_dir, tests[i]))
        plt.imshow(im, interpolation='nearest')
        plt.title('Training: 0: {:.3}, 1: {:.3}'.format(p0[i], p1[i]))
        plt.show()
    interact(view_image, i=(0,n-1))

# %%
browse_images(image_names)
